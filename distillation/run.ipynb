# %%
# !./train_sequential.sh
# Out:
# Training with config: config/convnext.yaml
# /home/arda/miniconda3/envs/distillation/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# [03/12 16:58 dinov2]: Starting DistillationTrainer initialization...
# [03/12 16:58 dinov2]: Starting config handling...
# [03/12 16:58 dinov2]: Config handled and updated.
# [03/12 16:58 dinov2]: Creating data transform...
# [03/12 16:58 dinov2]: Data transform created: <dinov2.data.augmentations.DataAugmentationDINO object at 0x7b50103c06a0>
# [03/12 16:58 dinov2]: Creating data module...
# [03/12 16:58 dinov2]: Data module created: <datasets.CustomDataset.CustomDataModule object at 0x7b50103e6590>
# [03/12 16:58 dinov2]: Creating teacher and student models...
# ...
