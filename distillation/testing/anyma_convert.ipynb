# %%
import torch
w = torch.load('/home/arda/dinov2/distillation/logs/stdc2/distillation/version_44/checkpoints/last.ckpt')
# Out:
# /home/arda/tmp/ipykernel_1788252/1188950314.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   w = torch.load('/home/arda/dinov2/distillation/logs/stdc2/distillation/version_44/checkpoints/last.ckpt')

# %%
w_student = {k: v for k, v in w['state_dict'].items() if 'student' in k and 'scalekd' not in k and 'feature_matchers' not in k}

# %%
w_student.keys()
# Out:
# dict_keys(['student.model.model.features.0.conv.weight', 'student.model.model.features.0.bn.weight', 'student.model.model.features.0.bn.bias', 'student.model.model.features.0.bn.running_mean', 'student.model.model.features.0.bn.running_var', 'student.model.model.features.0.bn.num_batches_tracked', 'student.model.model.features.1.conv.weight', 'student.model.model.features.1.bn.weight', 'student.model.model.features.1.bn.bias', 'student.model.model.features.1.bn.running_mean', 'student.model.model.features.1.bn.running_var', 'student.model.model.features.1.bn.num_batches_tracked', 'student.model.model.features.2.conv_list.0.conv.weight', 'student.model.model.features.2.conv_list.0.bn.weight', 'student.model.model.features.2.conv_list.0.bn.bias', 'student.model.model.features.2.conv_list.0.bn.running_mean', 'student.model.model.features.2.conv_list.0.bn.running_var', 'student.model.model.features.2.conv_list.0.bn.num_batches_tracked', 'student.model.model.features.2.conv_list.1.conv.weight', 'student.model.model.features.2.conv_list.1.bn.weight', 'student.model.model.features.2.conv_list.1.bn.bias', 'student.model.model.features.2.conv_list.1.bn.running_mean', 'student.model.model.features.2.conv_list.1.bn.running_var', 'student.model.model.features.2.conv_list.1.bn.num_batches_tracked', 'student.model.model.features.2.conv_list.2.conv.weight', 'student.model.model.features.2.conv_list.2.bn.weight', 'student.model.model.features.2.conv_list.2.bn.bias', 'student.model.model.features.2.conv_list.2.bn.running_mean', 'student.model.model.features.2.conv_list.2.bn.running_var', 'student.model.model.features.2.conv_list.2.bn.num_batches_tracked', 'student.model.model.features.2.conv_list.3.conv.weight', 'student.model.model.features.2.conv_list.3.bn.weight', 'student.model.model.features.2.conv_list.3.bn.bias', 'student.model.model.features.2.conv_list.3.bn.running_mean', 'student.model.model.features.2.conv_list.3.bn.running_var', 'student.model.model.features.2.conv_list.3.bn.num_batches_tracked', 'student.model.model.features.2.avd_layer.0.weight', 'student.model.model.features.2.avd_layer.1.weight', 'student.model.model.features.2.avd_layer.1.bias', 'student.model.model.features.2.avd_layer.1.running_mean', 'student.model.model.features.2.avd_layer.1.running_var', 'student.model.model.features.2.avd_layer.1.num_batches_tracked', 'student.model.model.features.3.conv_list.0.conv.weight', 'student.model.model.features.3.conv_list.0.bn.weight', 'student.model.model.features.3.conv_list.0.bn.bias', 'student.model.model.features.3.conv_list.0.bn.running_mean', 'student.model.model.features.3.conv_list.0.bn.running_var', 'student.model.model.features.3.conv_list.0.bn.num_batches_tracked', 'student.model.model.features.3.conv_list.1.conv.weight', 'student.model.model.features.3.conv_list.1.bn.weight', 'student.model.model.features.3.conv_list.1.bn.bias', 'student.model.model.features.3.conv_list.1.bn.running_mean', 'student.model.model.features.3.conv_list.1.bn.running_var', 'student.model.model.features.3.conv_list.1.bn.num_batches_tracked', 'student.model.model.features.3.conv_list.2.conv.weight', 'student.model.model.features.3.conv_list.2.bn.weight', 'student.model.model.features.3.conv_list.2.bn.bias', 'student.model.model.features.3.conv_list.2.bn.running_mean', 'student.model.model.features.3.conv_list.2.bn.running_var', 'student.model.model.features.3.conv_list.2.bn.num_batches_tracked', 'student.model.model.features.3.conv_list.3.conv.weight', 'student.model.model.features.3.conv_list.3.bn.weight', 'student.model.model.features.3.conv_list.3.bn.bias', 'student.model.model.features.3.conv_list.3.bn.running_mean', 'student.model.model.features.3.conv_list.3.bn.running_var', 'student.model.model.features.3.conv_list.3.bn.num_batches_tracked', 'student.model.model.features.4.conv_list.0.conv.weight', 'student.model.model.features.4.conv_list.0.bn.weight', 'student.model.model.features.4.conv_list.0.bn.bias', 'student.model.model.feat ...

# %%
# Convert ResNet50 weights from student model to Detectron2 format\
import pickle as pkl
detectron2_weights = {}

# Map the keys from student model to Detectron2 format
for k, v in w_student.items():
    # Remove the 'student.model.model.' prefix
    new_k = k.replace('student.model.model.', 'backbone.')
    
    # Handle stem weights
    if 'stem' in new_k:
        new_k = new_k.replace('conv1', 'conv1')
    
    # Handle residual blocks
    for i in range(2, 6):
        new_k = new_k.replace(f'res{i}', f'res{i}')
    
    detectron2_weights[new_k] = v.detach().cpu().numpy()

# Save in Detectron2 compatible format with metadata
res = {
    "model": detectron2_weights,
    "__author__": "dinov2_distillation",
    "matching_heuristics": True
}

with open("/home/arda/anyma/pretrained_models/STDCNet2.pkl", "wb") as f:
    pkl.dump(res, f)
